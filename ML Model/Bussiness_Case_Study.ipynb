# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

# Load the data
data = pd.read_csv('Audiobooks_data.csv')

# Rename the columns for clarity
data.columns = [
    'Customer ID',
    'Book length overall',
    'Book length avg',
    'Price paid overall',
    'Price paid avg',
    'Review',
    'Review out of 10',
    'Total minutes listened',
    'Completion',
    'Support requests',
    'Last visited minus purchase date',
    'Target'
]

# Drop the Customer ID (not useful for training)
inputs_all = data.iloc[:, 1:-1].values
targets_all = data.iloc[:, -1].values

# Balance the dataset: equal number of 0s and 1s
num_one_targets = int(np.sum(targets_all))
zero_targets_counter = 0
indices_to_remove = []

for i in range(targets_all.shape[0]):
    if targets_all[i] == 0:
        zero_targets_counter += 1
        if zero_targets_counter > num_one_targets:
            indices_to_remove.append(i)

inputs_balanced = np.delete(inputs_all, indices_to_remove, axis=0)
targets_balanced = np.delete(targets_all, indices_to_remove, axis=0)

# Scale the inputs
scaled_inputs = preprocessing.scale(inputs_balanced)

# Shuffle the data
shuffled_indices = np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)

inputs_shuffled = scaled_inputs[shuffled_indices]
targets_shuffled = targets_balanced[shuffled_indices]

# Split into train (80%), validation (10%), and test (10%)
train_inputs, temp_inputs, train_targets, temp_targets = train_test_split(
    inputs_shuffled, targets_shuffled, test_size=0.2, random_state=42)

validation_inputs, test_inputs, validation_targets, test_targets = train_test_split(
    temp_inputs, temp_targets, test_size=0.5, random_state=42)

# Build the model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(train_inputs.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')  # Output: probability (0-1)
])

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_inputs, train_targets,
                    validation_data=(validation_inputs, validation_targets),
                    batch_size=32,
                    epochs=50,
                    verbose=1)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print(f'\nTest Accuracy: {test_accuracy:.2f}')
print(f'Test Loss: {test_loss:.2f}')
# Out:
# Epoch 1/50
# D:\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6840 - loss: 0.6037 - val_accuracy: 0.7248 - val_loss: 0.4429
# Epoch 2/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7561 - loss: 0.4313 - val_accuracy: 0.7763 - val_loss: 0.3790
# Epoch 3/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7895 - loss: 0.3824 - val_accuracy: 0.7763 - val_loss: 0.3697
# Epoch 4/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7981 - loss: 0.3622 - val_accuracy: 0.8009 - val_loss: 0.3496
# Epoch 5/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8031 - loss: 0.3529 - val_accuracy: 0.8009 - val_loss: 0.3542
# Epoch 6/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8047 - loss: 0.3554 - val_accuracy: 0.7987 - val_loss: 0.3483
# Epoch 7/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8095 - loss: 0.3450 - val_accuracy: 0.8054 - val_loss: 0.3445
# Epoch 8/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8164 - loss: 0.3440 - val_accuracy: 0.8054 - val_loss: 0.3418
# Epoch 9/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8134 - loss: 0.3388 - val_accuracy: 0.8233 - val_loss: 0.3360
# Epoch 10/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8279 - loss: 0.3268 - val_accuracy: 0.8054 - val_loss: 0.3414
# Epoch 11/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8245 - loss: 0.3257 - val_accuracy: 0.7919 - val_loss: 0.3509
# Epoch 12/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8135 - loss: 0.3292 - val_accuracy: 0.8031 - val_loss: 0.3401
# Epoch 13/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8151 - loss: 0.3332 - val_accuracy: 0.7919 - val_loss: 0.3512
# Epoch 14/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8160 - loss: 0.3332 - val_accuracy: 0.8054 - val_loss: 0.3391
# Epoch 15/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8245 - loss: 0.3242 - val_accuracy: 0.8121 - val_loss: 0.3416
# Epoch 16/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8251 - loss: 0.3223 - val_accuracy: 0.8031 - val_loss: 0.3388
# Epoch 17/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8233 - loss: 0.3162 - val_accuracy: 0.8031 - val_loss: 0.3366
# Epoch 18/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8218 - loss: 0.3254 - val_accuracy: 0.7987 - val_loss: 0.3452
# Epoch 19/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8371 - loss: 0.3122 - val_accuracy: 0.8076 - val_loss: 0.3412
# Epoch 20/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8263 - loss: 0.3208 - val_accuracy: 0.8076 - val_loss: 0.3391
# Epoch 21/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8261 - loss: 0.3226 - val_accuracy: 0.8076 - val_loss: 0.3336
# Epoch 22/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8268 - loss: 0.3171 - val_accuracy: 0.8031 - val_loss: 0.3533
# Epoch 23/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8243 - loss: 0.3203 - val_accuracy: 0.8054 - val_loss: 0.3414
# Epoch 24/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8360 - loss: 0.3044 - val_accuracy: 0.8009 - val_loss: 0.3394
# Epoch 25/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8358 - loss: 0.3089 - val_accuracy: 0.8098 - val_loss: 0.3332
# Epoch 26/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8243 - loss: 0.3184 - val_accuracy: 0.8031 - val_loss: 0.3511
# Epoch 27/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8252 - loss: 0.3189 - val_accuracy: 0.8031 - val_loss: 0.3399
# Epoch 28/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8328 - loss: 0.3172 - val_accuracy: 0.8009 - val_loss: 0.3385
# Epoch 29/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8378 - loss: 0.3143 - val_accuracy: 0.8210 - val_loss: 0.3426
# Epoch 30/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8257 - loss: 0.3325 - val_accuracy: 0.8076 - val_loss: 0.3403
# Epoch 31/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8309 - loss: 0.3120 - val_accuracy: 0.8076 - val_loss: 0.3490
# Epoch 32/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8156 - loss: 0.3259 - val_accuracy: 0.7785 - val_loss: 0.3830
# Epoch 33/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8219 - loss: 0.3275 - val_accuracy: 0.7987 - val_loss: 0.3382
# Epoch 34/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8265 - loss: 0.3150 - val_accuracy: 0.8054 - val_loss: 0.3441
# Epoch 35/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8283 - loss: 0.3212 - val_accuracy: 0.8054 - val_loss: 0.3375
# Epoch 36/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8166 - loss: 0.3245 - val_accuracy: 0.8031 - val_loss: 0.3410
# Epoch 37/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8248 - loss: 0.3179 - val_accuracy: 0.7875 - val_loss: 0.3451
# Epoch 38/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8297 - loss: 0.3093 - val_accuracy: 0.8076 - val_loss: 0.3357
# Epoch 39/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8415 - loss: 0.3042 - val_accuracy: 0.8076 - val_loss: 0.3362
# Epoch 40/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8370 - loss: 0.3000 - val_accuracy: 0.7830 - val_loss: 0.3616
# Epoch 41/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8284 - loss: 0.3082 - val_accuracy: 0.8031 - val_loss: 0.3410
# Epoch 42/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8293 - loss: 0.3134 - val_accuracy: 0.7964 - val_loss: 0.3543
# Epoch 43/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8315 - loss: 0.3067 - val_accuracy: 0.7987 - val_loss: 0.3340
# Epoch 44/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8270 - loss: 0.3091 - val_accuracy: 0.7987 - val_loss: 0.3485
# Epoch 45/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8257 - loss: 0.3115 - val_accuracy: 0.7942 - val_loss: 0.3562
# Epoch 46/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8312 - loss: 0.3056 - val_accuracy: 0.8054 - val_loss: 0.3384
# Epoch 47/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8307 - loss: 0.3048 - val_accuracy: 0.8143 - val_loss: 0.3421
# Epoch 48/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8205 - loss: 0.3206 - val_accuracy: 0.8143 - val_loss: 0.3486
# Epoch 49/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8313 - loss: 0.2984 - val_accuracy: 0.8121 - val_loss: 0.3422
# Epoch 50/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8354 - loss: 0.3031 - val_accuracy: 0.8098 - val_loss: 0.3336
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8538 - loss: 0.3131
#
# Test Accuracy: 0.84
# Test Loss: 0.31
